# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data1 = pd.read_csv("C:/Users/samba/OneDrive/Desktop/TAMU CORPUS/Driscoll/sarima/datasets/CC_2021.csv")
data1
# Out:
#           Date       CC
# 0    3/26/2021   0.0032
# 1    3/27/2021   0.0221
# 2    3/28/2021   0.0410
# 3    3/29/2021   0.0599
# 4    3/30/2021   0.0788
# ..         ...      ...
# 111  7/15/2021  92.3780
# 112  7/16/2021  92.9260
# 113  7/17/2021  93.4740
# 114  7/18/2021  94.0220
# 115  7/19/2021  94.5700
#
# [116 rows x 2 columns]

# %%
data1 = data1.drop('labels',axis=1)
data1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [528], in <cell line: 1>()
# ----> 1 data1 = data1.drop('labels',axis=1)
#       2 data1
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
# ...

# %%
data1 = data1.T

# %%
data1 = data1.iloc[1:,:]
data1
# Out:
#           Date       CC
# 1    3/27/2021   0.0221
# 2    3/28/2021   0.0410
# 3    3/29/2021   0.0599
# 4    3/30/2021   0.0788
# 5    3/31/2021   0.0977
# ..         ...      ...
# 111  7/15/2021  92.3780
# 112  7/16/2021  92.9260
# 113  7/17/2021  93.4740
# 114  7/18/2021  94.0220
# 115  7/19/2021  94.5700
#
# [115 rows x 2 columns]

# %%
data1['average'] = data1.iloc[:,:].mean(axis=1)
# Out:
# C:\Users\samba\AppData\Local\Temp\ipykernel_14132\173415663.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data1['average'] = data1.iloc[:,:].mean(axis=1)
# C:\Users\samba\AppData\Local\Temp\ipykernel_14132\173415663.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['average'] = data1.iloc[:,:].mean(axis=1)

# %%
data1
# Out:
#           Date       CC  average
# 1    3/27/2021   0.0221   0.0221
# 2    3/28/2021   0.0410   0.0410
# 3    3/29/2021   0.0599   0.0599
# 4    3/30/2021   0.0788   0.0788
# 5    3/31/2021   0.0977   0.0977
# ..         ...      ...      ...
# 111  7/15/2021  92.3780  92.3780
# 112  7/16/2021  92.9260  92.9260
# 113  7/17/2021  93.4740  93.4740
# 114  7/18/2021  94.0220  94.0220
# 115  7/19/2021  94.5700  94.5700
#
# [115 rows x 3 columns]

# %%
data1 = data1[34:51]

# %%
data1
# Out:
#                 0         1         2         3         4         5         6  \
# 0eg21   -0.009223 -0.009480 -0.014338 -0.019320 -0.006268 -0.007126 -0.014152
# 13eg21  -0.012479 -0.013097 -0.020128 -0.019525 -0.015423 -0.010119 -0.014826
# 25eg21   0.000898 -0.005670 -0.005601 -0.005686 -0.002013 -0.004797 -0.003075
# 35eg21   0.005311 -0.004000 -0.005358  0.007831  0.002070 -0.003905  0.000052
# 41eg21   0.015066 -0.005264 -0.011804 -0.007433  0.019189 -0.003028 -0.009024
# 49eg21   0.039372  0.009280 -0.003156 -0.002268  0.069922  0.001907  0.000216
# 55eg21   0.057240  0.017469  0.003763 -0.001848  0.074321  0.009041  0.010141
# 62eg21   0.109436  0.044049  0.014211  0.007903  0.097682  0.022772  0.022214
# 69eg21   0.138207  0.070538  0.039325  0.019774  0.118045  0.034542  0.035263
# 77eg21   0.125951  0.061718  0.030983  0.016579  0.053834  0.033118  0.036956
# 84eg21   0.133590  0.057969  0.021924  0.020474  0.036394  0.039956  0.037443
# ...

# %%
data1['average_eg'] = data1['average']
# Out:
# C:\Users\samba\AppData\Local\Temp\ipykernel_19732\2134930401.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['average_eg'] = data1['average']

# %%
data1
# Out:
#                 0         1         2         3         4         5         6  \
# 0eg21   -0.009223 -0.009480 -0.014338 -0.019320 -0.006268 -0.007126 -0.014152
# 13eg21  -0.012479 -0.013097 -0.020128 -0.019525 -0.015423 -0.010119 -0.014826
# 25eg21   0.000898 -0.005670 -0.005601 -0.005686 -0.002013 -0.004797 -0.003075
# 35eg21   0.005311 -0.004000 -0.005358  0.007831  0.002070 -0.003905  0.000052
# 41eg21   0.015066 -0.005264 -0.011804 -0.007433  0.019189 -0.003028 -0.009024
# 49eg21   0.039372  0.009280 -0.003156 -0.002268  0.069922  0.001907  0.000216
# 55eg21   0.057240  0.017469  0.003763 -0.001848  0.074321  0.009041  0.010141
# 62eg21   0.109436  0.044049  0.014211  0.007903  0.097682  0.022772  0.022214
# 69eg21   0.138207  0.070538  0.039325  0.019774  0.118045  0.034542  0.035263
# 77eg21   0.125951  0.061718  0.030983  0.016579  0.053834  0.033118  0.036956
# 84eg21   0.133590  0.057969  0.021924  0.020474  0.036394  0.039956  0.037443
# ...

# %%
data2 = data1['average_eg']

# %%
data2
# Out:
# 0eg21     -0.012291
# 13eg21    -0.009463
# 25eg21    -0.001042
# 35eg21     0.037928
# 41eg21     0.048513
# 49eg21     0.088002
# 55eg21     0.103108
# 62eg21     0.124217
# 69eg21     0.098599
# 77eg21     0.085248
# 84eg21     0.102595
# 91eg21     0.120866
# 97eg21     0.118285
# 106eg21    0.153568
# 111eg21    0.147883
# 116eg21    0.184029
# 124eg21    0.022070
# Name: average_eg, dtype: float64

# %%
data2.to_csv('2021_avg_eg_5.csv')

# %%
data1 = pd.read_csv("C:/Users/samba/OneDrive/Desktop/TAMU CORPUS/Driscoll/sarima/datasets/CC_2021.csv")
data2 = data1

# %%
data2 = pd.DataFrame(data2)

# %%
data2
# Out:
#           Date       CC
# 0    3/26/2021   0.0032
# 1    3/27/2021   0.0221
# 2    3/28/2021   0.0410
# 3    3/29/2021   0.0599
# 4    3/30/2021   0.0788
# ..         ...      ...
# 111  7/15/2021  92.3780
# 112  7/16/2021  92.9260
# 113  7/17/2021  93.4740
# 114  7/18/2021  94.0220
# 115  7/19/2021  94.5700
#
# [116 rows x 2 columns]

# %%
data2['Date'] = pd.to_datetime(data2['Date'])
data2.index = data2['Date']

# %%
data2.drop(['Date'], axis = 1,inplace = True)

# %%
from sklearn.model_selection import train_test_split
dataset_train, dataset_test = train_test_split(data2, test_size=0.095, shuffle=False)

# %%
training_set = dataset_train.values
training_set
# Out:
# array([[3.20000000e-03],
#        [2.21000000e-02],
#        [4.10000000e-02],
#        [5.99000000e-02],
#        [7.88000000e-02],
#        [9.77000000e-02],
#        [1.16600000e-01],
#        [1.35500000e-01],
#        [1.54400000e-01],
#        [1.73300000e-01],
#        [1.92200000e-01],
#        [2.11100000e-01],
#        [2.30000000e-01],
#        [9.60000000e-01],
#        [1.69000000e+00],
#        [2.42000000e+00],
#        [3.15000000e+00],
#        [3.88000000e+00],
#        [4.61000000e+00],
#        [5.34000000e+00],
#        [6.07000000e+00],
#        [6.80000000e+00],
#        [7.53000000e+00],
#        [8.26000000e+00],
#        [8.99000000e+00],
#        [9.54000000e+00],
#        [1.00900000e+01],
#        [1.06400000e+01],
#        [1.11900000e+01],
#        [1.17400000e+01],
#        [1.22900000e+01],
#        [1.28400000e+01],
#        [1.33900000e+01],
#        [1.39400000e+01],
#        [1.44900000e+01],
#        [1.58466667e+01],
#        [1.72033333e+01],
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %%
X_train = []
y_train = []
for i in range(1, len(training_set_scaled)):
    X_train.append(training_set_scaled[i-1:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
print (X_train)
# Out:
# [[[0.00000000e+00]]
#
#  [[2.07289574e-04]]
#
#  [[4.14579147e-04]]
#
#  [[6.21868721e-04]]
#
#  [[8.29158295e-04]]
#
#  [[1.03644787e-03]]
#
#  [[1.24373744e-03]]
#
#  [[1.45102702e-03]]
#
#  [[1.65831659e-03]]
#
#  [[1.86560616e-03]]
#
#  [[2.07289574e-03]]
#
#  [[2.28018531e-03]]
#
#  [[2.48747488e-03]]
#
#  [[1.04938976e-02]]
#
#  [[1.85003203e-02]]
#
#  [[2.65067429e-02]]
#
#  [[3.45131656e-02]]
#
#  [[4.25195883e-02]]
#
#  [[5.05260110e-02]]
#
#  [[5.85324337e-02]]
#
#  [[6.65388564e-02]]
#
#  [[7.45452791e-02]]
#
#  [[8.25517017e-02]]
#
#  [[9.05581244e-02]]
#
#  [[9.85645471e-02]]
#
#  [[1.04596783e-01]]
#
#  [[1.10629020e-01]]
#
#  [[1.16661256e-01]]
#
#  [[1.22693492e-01]]
#
#  [[1.28725728e-01]]
#
#  [[1.34757965e-01]]
#
#  [[1.40790201e-01]]
#
#  [[1.46822437e-01]]
#
#  [[1.52854674e-01]]
#
#  [[1.58886910e-01]]
#
#  [[1.73766426e-01]]
#
#  [[1.88645942e-01]]
#
#  [[2.03525458e-01]]
#
#  [[2.18404974e-01]]
#
#  [[2.33284490e-01]]
#
#  [[2.48164007e-01]]
#
# ...

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Dense

# %%
#stacked LSTM
model = Sequential()
model.add(LSTM(units=50,return_sequences=True,input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.1))
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.1))
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.1))
model.add(LSTM(units=50))
model.add(Dropout(0.1))
model.add(Dense(units=1))
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(X_train,y_train,epochs=50,batch_size=4)
# Out:
# Epoch 1/50
# 26/26 [==============================] - 6s 3ms/step - loss: 0.3673
# Epoch 2/50
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1992
# Epoch 3/50
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0731
# Epoch 4/50
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0426
# Epoch 5/50
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0203
# Epoch 6/50
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0102
# Epoch 7/50
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0091
# Epoch 8/50
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 9/50
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0103
# Epoch 10/50
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0098
# Epoch 11/50
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0074
# Epoch 12/50
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0068
# ...

# %%
real_average_eg = dataset_test.values

# %%
real_average_eg
# Out:
# array([[91.27285714],
#        [91.36571429],
#        [91.45857143],
#        [91.55142857],
#        [91.64428571],
#        [91.73714286],
#        [91.83      ],
#        [92.378     ],
#        [92.926     ],
#        [93.474     ],
#        [94.022     ],
#        [94.57      ]])

# %%
dataset_test
# Out:
#                    CC
# Date
# 2021-07-08  91.272857
# 2021-07-09  91.365714
# 2021-07-10  91.458571
# 2021-07-11  91.551429
# 2021-07-12  91.644286
# 2021-07-13  91.737143
# 2021-07-14  91.830000
# 2021-07-15  92.378000
# 2021-07-16  92.926000
# 2021-07-17  93.474000
# 2021-07-18  94.022000
# 2021-07-19  94.570000

# %%
dataset_total = pd.concat((dataset_train['CC'], dataset_test['CC']), axis = 0)

# %%
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 1:].values

# %%
inputs = inputs.reshape(-1,1)

# %%
inputs = sc.transform(inputs)

# %%
X_test = []
for i in range(1, len(dataset_test)+1):
    X_test.append(inputs[i-1:i, 0])

# %%
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_average_eg = model.predict(X_test)
predicted_average_eg = sc.inverse_transform(predicted_average_eg)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
predicted_average_eg
predicted_average_eg_1 = pd.DataFrame(predicted_average_eg)
predicted_average_eg_1.to_csv('7.csv')

# %%
real_average_eg
# Out:
# array([[88.77166667],
#        [89.12333333],
#        [89.475     ],
#        [89.82666667],
#        [90.17833333],
#        [90.53      ],
#        [90.62285714],
#        [90.71571429],
#        [90.80857143],
#        [90.90142857],
#        [90.99428571],
#        [91.08714286],
#        [91.18      ],
#        [91.27285714],
#        [91.36571429],
#        [91.45857143],
#        [91.55142857],
#        [91.64428571],
#        [91.73714286],
#        [91.83      ],
#        [92.378     ],
#        [92.926     ],
#        [93.474     ],
#        [94.022     ],
#        [94.57      ]])

# %%
plt.plot(real_average_eg, color = 'black', label = 'Real Excessive Green Index')
plt.plot(predicted_average_eg, color = 'green', label = 'Predicted Excessive Green Index')
plt.title('Canopy Cover for 2021')
plt.xlabel('Time')
plt.ylabel('Canopy Cover')
plt.legend()
plt.show()
